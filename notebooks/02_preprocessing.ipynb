# %% [markdown]
# # 02 - Data Preprocessing & Feature Engineering
#
# This notebook handles data preprocessing including:
# - Missing value handling
# - Skills multi-hot encoding with frequency filtering
# - Categorical encoding (ordinal and one-hot)
# - Feature scaling
# - Train/test split

# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. Load Dataset

# %%
df = pd.read_csv('../data/ai_job_dataset.csv')
print(f"Original dataset shape: {df.shape}")
df.head()
# Out:
# Original dataset shape: (15000, 19)
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
# 2  AI00003          AI Specialist      152626             USD
# 3  AI00004           NLP Engineer       80215             USD
# 4  AI00005          AI Consultant       54624             EUR
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
# 2               MI              FL      Switzerland            L
# 3               SE              FL            India            M
# 4               EN              PT           France            S
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
# 2        South Korea             0
# ...

# %% [markdown]
# ## 2. Select Features & Target

# %%
# Columns to drop (identifiers, leakage-prone, low predictive value)
drop_cols = ['job_id', 'salary_currency', 'employee_residence', 'posting_date', 
             'application_deadline', 'job_description_length', 'company_name']

# Target variable
target = 'salary_usd'

# Create working dataframe
df_work = df.drop(columns=drop_cols)
print(f"Working dataset shape: {df_work.shape}")
print(f"\nColumns: {df_work.columns.tolist()}")
# Out:
# Working dataset shape: (15000, 12)
#
# Columns: ['job_title', 'salary_usd', 'experience_level', 'employment_type', 'company_location', 'company_size', 'remote_ratio', 'required_skills', 'education_required', 'years_experience', 'industry', 'benefits_score']

# %% [markdown]
# ## 3. Missing Value Handling

# %%
# Check missing values
missing = df_work.isnull().sum()
missing_pct = (missing / len(df_work)) * 100
missing_df = pd.DataFrame({'Missing Count': missing, 'Missing %': missing_pct})
print("Missing values summary:")
print(missing_df[missing_df['Missing Count'] > 0].sort_values('Missing %', ascending=False))

if missing.sum() == 0:
    print("\nNo missing values found!")
# Out:
# Missing values summary:
# Empty DataFrame
# Columns: [Missing Count, Missing %]
# Index: []
#
# No missing values found!

# %% [markdown]
# ## (New) 4. Job-title

# %%
job_list = df_work['job_title'].unique()
job_df = df_work[['job_title']]
job_list
# Out:
# array(['AI Research Scientist', 'AI Software Engineer', 'AI Specialist',
#        'NLP Engineer', 'AI Consultant', 'AI Architect',
#        'Principal Data Scientist', 'Data Analyst',
#        'Autonomous Systems Engineer', 'AI Product Manager',
#        'Machine Learning Engineer', 'Data Engineer', 'Research Scientist',
#        'ML Ops Engineer', 'Robotics Engineer', 'Head of AI',
#        'Deep Learning Engineer', 'Data Scientist',
#        'Machine Learning Researcher', 'Computer Vision Engineer'],
#       dtype=object)

# %%
job_list = df_work['job_title'].unique()
job_df = df_work[['job_title']]
job_list

job_dic = {'AI': ['AI'],
           'Data': ['Data'],
           'ML': ['ML', 'Machine Learning'],
           'Research': ['Research'], 
           'Analyst': ['Analyst'],
           'Engineer': ['Engineer'],
           'Scientist': ['Scientist'],
           'NLP': ['NLP'],
           'Robotics': ['Robotics'],
           'Specialist': ['Specialist'],
           'Autonomous': ['Autonomous'],
           'Deep_learning': ['Deep Learning']}

for col, keywords in job_dic.items():
    pattern = '|'.join(keywords)
    job_df[f'title_{col}'] = job_df['job_title'].str.contains(pattern, case=False, regex=True).astype(int)
job_df = job_df.drop(columns=['job_title'])

# %% [markdown]
# ## (Shifted) 5. Train / Validation / Test Split (70/10/20)

# %%
X = pd.concat([
    job_df,
    df_work.drop(columns=['salary_usd','job_title'])
], axis=1)
y = df_work['salary_usd']


# Two-stage split: first 70/30, then split the 30 into 10 val + 20 test
strat_col = df_work['experience_level']

# Stage 1: 70% train, 30% temp
X_train, X_temp, y_train, y_temp, strat_train, strat_temp = train_test_split(
    X, y, strat_col,
    test_size=0.30,
    random_state=42,
    stratify=strat_col
)

# Stage 2: split 30% into 1/3 val (10% overall) + 2/3 test (20% overall)
X_val, X_test, y_val, y_test, strat_val, strat_test = train_test_split(
    X_temp, y_temp, strat_temp,
    test_size=2/3,
    random_state=42,
    stratify=strat_temp
)

print(f"Training set:   {X_train.shape[0]} samples ({X_train.shape[0]/len(X)*100:.0f}%)")
print(f"Validation set: {X_val.shape[0]} samples ({X_val.shape[0]/len(X)*100:.0f}%)")
print(f"Test set:       {X_test.shape[0]} samples ({X_test.shape[0]/len(X)*100:.0f}%)")
print(f"\nTarget (log-scale) distribution in training set:")
print(y_train.describe())
# Out:
# Training set:   10500 samples (70%)
# Validation set: 1500 samples (10%)
# Test set:       3000 samples (20%)
#
# Target (log-scale) distribution in training set:
# count     10500.000000
# mean     115317.262000
# std       60150.695316
# min       32542.000000
# 25%       70204.250000
# 50%       99571.000000
# 75%      146378.500000
# max      398084.000000
# Name: salary_usd, dtype: float64

# %% [markdown]
# ## (Shifted) 6. Outlier Handling (IQR-Based Capping)
#
# Cap extreme salary values using the IQR method (winsorization) to reduce the impact of outliers without dropping rows.

# %%
# IQR-based winsorization on salary_usd
Q1 = y_train.quantile(0.25)
Q3 = y_train.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_below = (y_train < lower_bound).sum()
outliers_above = (y_train > upper_bound).sum()
print(f"Salary IQR bounds: [{lower_bound:,.0f}, {upper_bound:,.0f}]")
print(f"Outliers below: {outliers_below}, above: {outliers_above}")

# Cap (winsorize) instead of dropping
y_train = y_train.clip(lower=lower_bound, upper=upper_bound)
y_val = y_val.clip(lower=lower_bound, upper=upper_bound)
y_test = y_test.clip(lower=lower_bound, upper=upper_bound)

print(f"\nAfter capping y_train:")
print(y_train.describe())

print(f"\nAfter capping y_val:")
print(y_val.describe())

print(f"\nAfter capping y_test:")
print(y_test.describe())
# Out:
# Salary IQR bounds: [-44,057, 260,640]
# Outliers below: 0, above: 332
#
# After capping y_train:
# count     10500.000000
# mean     114153.477667
# std       56633.834804
# min       32542.000000
# 25%       70204.250000
# 50%       99571.000000
# 75%      146378.500000
# max      260639.875000
# Name: salary_usd, dtype: float64
#
# After capping y_val:
# count      1500.000000
# mean     113088.552000
# std       55617.059417
# min       32519.000000
# 25%       70641.500000
# 50%       98287.000000
# 75%      146064.750000
# max      260639.875000
# Name: salary_usd, dtype: float64
#
# After capping y_test:
# count      3000.000000
# mean     114525.845583
# std       56706.483316
# min       32692.000000
# 25%       69804.250000
# 50%      100414.000000
# 75%      146448.250000
# max      260639.875000
# Name: salary_usd, dtype: float64

# %% [markdown]
# ## (Shifted) 7. Salary Log-Transform
#
# Apply `log1p` to normalize the right-skewed salary distribution. Models will be trained on log-scale; predictions will be inverse-transformed back to dollars for evaluation.

# %%
# Apply log1p transform to salary
# df_work['salary_log'] = np.log1p(df_work['salary_usd'])
y_train_log = np.log1p(y_train)
y_val_log = np.log1p(y_val)
y_test_log = np.log1p(y_test)

print("Salary distribution (train) before and after log transform:")
print(f"  salary_usd  — skew: {y_train.skew():.3f}, mean: ${y_train.mean():,.0f}")
print(f"  salary_log  — skew: {y_train_log.skew():.3f}, mean: {y_train_log.mean():.4f}")
# print(f"  salary_usd  — skew: {df_work['salary_usd'].skew():.3f}, mean: ${df_work['salary_usd'].mean():,.0f}")
# print(f"  salary_log  — skew: {df_work['salary_log'].skew():.3f}, mean: {df_work['salary_log'].mean():.4f}")

# # Keep original salary for later inverse-transform evaluation
# df_work['salary_original'] = df_work['salary_usd']
# Out:
# Salary distribution (train) before and after log transform:
#   salary_usd  — skew: 0.941, mean: $114,153
#   salary_log  — skew: 0.054, mean: 11.5275

# %% [markdown]
# ## (Replaced) 8. Skills Multi-Hot Encoding

# %%
# Extract all unique skills and their frequencies
def extract_skills(df):
    all_skills = []
    for skills_str in df['required_skills']:
        skills = [s.strip() for s in skills_str.split(',')]
        all_skills.extend(skills)
    return pd.Series(all_skills).value_counts()

skill_counts = extract_skills(df_work)
print(f"Total unique skills: {len(skill_counts)}")
print(f"\nSkill frequency distribution:")
print(skill_counts.describe())
# Out:
# Total unique skills: 24
#
# Skill frequency distribution:
# count      24.000000
# mean     2495.541667
# std       572.221603
# min      1833.000000
# 25%      2152.500000
# 50%      2326.000000
# 75%      2723.000000
# max      4450.000000
# Name: count, dtype: float64

# %%
# Filter skills that appear in at least 2% of samples
min_freq = 0.02 * len(df_work)
frequent_skills = skill_counts[skill_counts >= min_freq].index.tolist()
print(f"Skills appearing in >= 2% of samples: {len(frequent_skills)}")
print(f"Frequent skills: {frequent_skills}")
# Out:
# Skills appearing in >= 2% of samples: 24
# Frequent skills: ['Python', 'SQL', 'TensorFlow', 'Kubernetes', 'Scala', 'PyTorch', 'Linux', 'Git', 'Java', 'GCP', 'Hadoop', 'Tableau', 'R', 'Computer Vision', 'Data Visualization', 'Deep Learning', 'MLOps', 'Spark', 'NLP', 'Azure', 'AWS', 'Mathematics', 'Docker', 'Statistics']

# %%
# def encode_skills(df, frequent_skills):
#     """
#     Multi-hot encode skills.
#     Returns a DataFrame with binary columns for each frequent skill,
#     plus a count of rare skills.
#     """
#     skill_matrix = pd.DataFrame(index=df.index)
    
#     for skill in frequent_skills:
#         skill_col = f"skill_{skill.replace(' ', '_').replace('-', '_').lower()}"
#         skill_matrix[skill_col] = df['required_skills'].apply(
#             lambda x: 1 if skill in [s.strip() for s in x.split(',')] else 0
#         )
    
#     # # Count rare skills (those not in frequent_skills)
#     # def count_rare_skills(skills_str):
#     #     skills = [s.strip() for s in skills_str.split(',')]
#     #     rare_count = sum(1 for s in skills if s not in frequent_skills)
#     #     return rare_count
    
#     # skill_matrix['other_skills_count'] = df['required_skills'].apply(count_rare_skills)
    
#     return skill_matrix

# # Encode skills
# skills_encoded = encode_skills(df_work, frequent_skills)
# print(f"Skills encoded shape: {skills_encoded.shape}")
# skills_encoded.head()

# skills_encoded_train = encode_skills(X_train, frequent_skills)
# skills_encoded_val = encode_skills(X_val, frequent_skills)
# skills_encoded_test = encode_skills(X_test, frequent_skills)

# # adding the skills stacks back into the X dfs
# X_train = pd.concat([X_train.drop(columns=['required_skills']), skills_encoded_train], axis=1)
# X_val = pd.concat([X_val.drop(columns=['required_skills']), skills_encoded_val], axis=1)
# X_test = pd.concat([X_test.drop(columns=['required_skills']), skills_encoded_test], axis=1)

# %% [markdown]
# ## (New) 8a. Skills stack

# %%
skills_dict = {'deep_learning': ['PyTorch', 'TensorFlow', 'Deep Learning', 'NLP', 'Computer Vision', 'MLOps'],
               'big_data': ['Spark', 'Hadoop', 'Scala', 'Java'],
               'cloud': ['AWS', 'Azure', 'GCP', 'Docker', 'Kubernetes', 'Linux', 'Git'],
               'data':['Python', 'R', 'SQL', 'Statistics', 'Mathematics', 'Data Visualisation', 'Tableau']
              }

# %%
def count_skills_per_stack(df, column, skills_dict):
    skills_dict_lower = {k: [s.lower() for s in v] for k, v in skills_dict.items()}
    
    counts_df = pd.DataFrame(index=df.index)
    
    for stack, skills in skills_dict_lower.items():
        counts_df[f'skills_{stack}_count'] = df[column].apply(
            lambda x: sum(skill in x.lower() for skill in skills)
        )
    
    return counts_df

X_train_skills_count = count_skills_per_stack(X_train, 'required_skills', skills_dict)
X_val_skills_count = count_skills_per_stack(X_val, 'required_skills', skills_dict)
X_test_skills_count = count_skills_per_stack(X_test, 'required_skills', skills_dict)

# adding the skills stacks back into the X dfs
X_train = pd.concat([X_train.drop(columns=['required_skills']), X_train_skills_count], axis=1)
X_val = pd.concat([X_val.drop(columns=['required_skills']), X_val_skills_count], axis=1)
X_test = pd.concat([X_test.drop(columns=['required_skills']), X_test_skills_count], axis=1)
print(X_train_skills_count)
# Out:
#        skills_deep_learning_count  skills_big_data_count  skills_cloud_count  \
# 1472                            1                      1                   1
# 888                             3                      1                   0
# 6676                            0                      0                   1
# 12103                           0                      1                   0
# 3553                            0                      2                   1
# ...                           ...                    ...                 ...
# 4058                            1                      1                   2
# 2504                            0                      2                   0
# 13691                           2                      0                   1
# 10764                           1                      0                   1
# 11637                           1                      1                   0
#
#        skills_data_count
# ...

# %% [markdown]
# ## (Shifted) 9. Ordinal Encoding

# %%
# Define ordinal mappings
experience_order = ['EN', 'MI', 'SE', 'EX']  # Entry -> Executive
education_order = ['Associate', 'Bachelor', 'Master', 'PhD']  # Low -> High

# Apply ordinal encoding
X_train['experience_level_enc'] = X_train['experience_level'].map({v: i for i, v in enumerate(experience_order)})
X_val['experience_level_enc'] = X_val['experience_level'].map({v: i for i, v in enumerate(experience_order)})
X_test['experience_level_enc'] = X_test['experience_level'].map({v: i for i, v in enumerate(experience_order)})

X_train['education_required_enc'] = X_train['education_required'].map({v: i for i, v in enumerate(education_order)})
X_val['education_required_enc'] = X_val['education_required'].map({v: i for i, v in enumerate(education_order)})
X_test['education_required_enc'] = X_test['education_required'].map({v: i for i, v in enumerate(education_order)})
# df_work['experience_level_enc'] = df_work['experience_level'].map(
#     {v: i for i, v in enumerate(experience_order)}
# )
# df_work['education_required_enc'] = df_work['education_required'].map(
#     {v: i for i, v in enumerate(education_order)}
# )

print("Experience level(train) encoding:")
print(X_train[['experience_level', 'experience_level_enc']].drop_duplicates().sort_values('experience_level_enc'))
print("\nEducation(train) encoding:")
print(X_train[['education_required', 'education_required_enc']].drop_duplicates().sort_values('education_required_enc'))
# print("Experience level encoding:")
# print(df_work[['experience_level', 'experience_level_enc']].drop_duplicates().sort_values('experience_level_enc'))
# print("\nEducation encoding:")
# print(df_work[['education_required', 'education_required_enc']].drop_duplicates().sort_values('education_required_enc'))

X_train = X_train.drop(columns=['experience_level'])
X_val = X_val.drop(columns=['experience_level'])
X_test = X_test.drop(columns=['experience_level'])
X_train = X_train.drop(columns=['education_required'])
X_val = X_val.drop(columns=['education_required'])
X_test = X_test.drop(columns=['education_required'])
# Out:
# Experience level(train) encoding:
#       experience_level  experience_level_enc
# 888                 EN                     0
# 1472                MI                     1
# 12103               SE                     2
# 5624                EX                     3
#
# Education(train) encoding:
#      education_required  education_required_enc
# 1472          Associate                       0
# 3553           Bachelor                       1
# 6676             Master                       2
# 3312                PhD                       3

# %% [markdown]
# ## (Shifted) 10. One-Hot Encoding for Nominal Categoricals

# %%
# Columns to one-hot encode
# onehot_cols = ['job_title', 'company_location', 'industry', 'employment_type', 'company_size']
onehot_cols = ['company_location', 'industry', 'employment_type', 'company_size']

# Convert remote_ratio to categorical (it's essentially categorical)
# df_work['remote_ratio'] = df_work['remote_ratio'].astype(str)
X_train['remote_ratio'] = X_train['remote_ratio'].astype(str)
X_val['remote_ratio'] = X_val['remote_ratio'].astype(str)
X_test['remote_ratio'] = df_work['remote_ratio'].astype(str)
onehot_cols.append('remote_ratio')

# Initialize encoder
ohe = OneHotEncoder(sparse_output=False ,drop='first', handle_unknown='ignore')

# Fit on training data
ohe.fit(X_train[onehot_cols])

X_train_ohe = pd.DataFrame(ohe.transform(X_train[onehot_cols]),
                           columns=ohe.get_feature_names_out(onehot_cols),
                           index=X_train.index)

X_val_ohe = pd.DataFrame(ohe.transform(X_val[onehot_cols]),
                         columns=ohe.get_feature_names_out(onehot_cols),
                         index=X_val.index)

X_test_ohe = pd.DataFrame(ohe.transform(X_test[onehot_cols]),
                          columns=ohe.get_feature_names_out(onehot_cols),
                          index=X_test.index)


print(f"One-hot encoded shape: {X_train_ohe.shape}")
print(f"One-hot columns: {X_train_ohe.columns.tolist()[:10]}...")

# One-hot encode
# df_onehot = pd.get_dummies(df_work[onehot_cols], prefix=onehot_cols, drop_first=True)
# print(f"One-hot encoded shape: {df_onehot.shape}")
# print(f"One-hot columns: {df_onehot.columns.tolist()[:10]}...")

X_train = pd.concat([X_train.drop(columns=onehot_cols), X_train_ohe], axis=1)
X_val = pd.concat([X_val.drop(columns=onehot_cols), X_val_ohe], axis=1)
X_test = pd.concat([X_test.drop(columns=onehot_cols), X_test_ohe], axis=1)
# Out:
# One-hot encoded shape: (10500, 40)
# One-hot columns: ['company_location_Austria', 'company_location_Canada', 'company_location_China', 'company_location_Denmark', 'company_location_Finland', 'company_location_France', 'company_location_Germany', 'company_location_India', 'company_location_Ireland', 'company_location_Israel']...

# %% [markdown]
# ## (Shifted) 11. Feature Scaling

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10500 entries, 1472 to 11637
# Data columns (total 60 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   title_AI                         10500 non-null  int64
#  1   title_Data                       10500 non-null  int64
#  2   title_ML                         10500 non-null  int64
#  3   title_Research                   10500 non-null  int64
#  4   title_Analyst                    10500 non-null  int64
#  5   title_Engineer                   10500 non-null  int64
#  6   title_Scientist                  10500 non-null  int64
#  7   title_NLP                        10500 non-null  int64
#  8   title_Robotics                   10500 non-null  int64
#  9   title_Specialist                 10500 non-null  int64
#  10  title_Autonomous                 10500 non-null  int64
#  11  title_Deep_learning              10500 non-null  int64
# ...

# %%
# Scale numerical features (for linear models and MLP)
# Tree-based models don't need scaling, but we'll create scaled version anyway

scaler = StandardScaler()

# Columns to scale
# cols_to_scale = numerical_cols + ['other_skills_count']
numerical_cols = ['years_experience', 'benefits_score', 'skills_deep_learning_count', 'skills_big_data_count', 'skills_cloud_count', 'skills_data_count']

cols_to_scale = numerical_cols 

# Fit scaler on training data only
X_train_scaled = X_train.copy()
X_val_scaled = X_val.copy()
X_test_scaled = X_test.copy()

X_train_scaled[cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])
X_val_scaled[cols_to_scale] = scaler.transform(X_val[cols_to_scale])
X_test_scaled[cols_to_scale] = scaler.transform(X_test[cols_to_scale])

print("Scaling applied to:", cols_to_scale)
print(f"\nScaled training data sample statistics for 'years_experience':")
print(f"  Mean: {X_train_scaled['years_experience'].mean():.4f}")
print(f"  Std: {X_train_scaled['years_experience'].std():.4f}")
# Out:
# Scaling applied to: ['years_experience', 'benefits_score', 'skills_deep_learning_count', 'skills_big_data_count', 'skills_cloud_count', 'skills_data_count']
#
# Scaled training data sample statistics for 'years_experience':
#   Mean: -0.0000
#   Std: 1.0000

# %% [markdown]
# ## (Changed) 12. Features Summary

# %%
# Numerical features
numerical_cols = ['years_experience', 'benefits_score', 'skills_deep_learning_count', 'skills_big_data_count', 
                  'skills_cloud_count', 'skills_data_count']

# Ordinal encoded features
ordinal_cols = ['experience_level_enc', 'education_required_enc']

# One-hot encoded features
ohe_cols = [col for col in X_train.columns if col not in['years_experience', 'benefits_score', 'skills_deep_learning_count', 
                                                         'skills_big_data_count', 'skills_cloud_count', 'skills_data_count',
                                                         'experience_level_enc', 'education_required_enc']]

# # Combine all features
# X = pd.concat([
#     job_df,
#     df_work[numerical_cols],
#     df_work[ordinal_cols],
#     df_onehot,
#     # skills_encoded,
#     skills_count_df
# ], axis=1)

# # Use log-transformed salary as target for training
# y = df_work['salary_log']

# # Keep original-scale salary for evaluation
# y_original = df_work['salary_original']

print(f"Final feature matrix shape: {X_train.shape}")
print(f"Target shape (log-scale): {y_train_log.shape}")
print(f"Target shape (original $): {y_train.shape}")
# Out:
# Final feature matrix shape: (10500, 60)
# Target shape (log-scale): (10500,)
# Target shape (original $): (10500,)

# %%
# Display feature summary
print("Feature categories:")
print(f"  - Numerical: {len(numerical_cols)} features")
print(f"  - Ordinal encoded: {len(ordinal_cols)} features")
print(f"  - One-hot encoded: {len(ohe_cols)} features")
# print(f"  - Skills encoded: {skills_encoded.shape[1]} features")
print(f"  - Total: {X_train.shape[1]} features")
# Out:
# Feature categories:
#   - Numerical: 6 features
#   - Ordinal encoded: 2 features
#   - One-hot encoded: 52 features
#   - Total: 60 features

# %% [markdown]
# ## 10. Save Preprocessed Data

# %%
import os

# Create output directory
os.makedirs('../data/processed', exist_ok=True)

# Save unscaled data (for tree-based models)
X_train.to_csv('../data/processed/X_train.csv', index=False)
X_val.to_csv('../data/processed/X_val.csv', index=False)
X_test.to_csv('../data/processed/X_test.csv', index=False)

# Save log-scale targets (for model training)
y_train_log.to_csv('../data/processed/y_train.csv', index=False)
y_val_log.to_csv('../data/processed/y_val.csv', index=False)
y_test_log.to_csv('../data/processed/y_test.csv', index=False)
# y_train.to_csv('../data/processed/y_train.csv', index=False)
# y_val.to_csv('../data/processed/y_val.csv', index=False)
# y_test.to_csv('../data/processed/y_test.csv', index=False)

# Save original-scale targets (for evaluation in dollar terms)
y_train.to_csv('../data/processed/y_train_original.csv', index=False)
y_val.to_csv('../data/processed/y_val_original.csv', index=False)
y_test.to_csv('../data/processed/y_test_original.csv', index=False)
# y_train_original.to_csv('../data/processed/y_train_original.csv', index=False)
# y_val_original.to_csv('../data/processed/y_val_original.csv', index=False)
# y_test_original.to_csv('../data/processed/y_test_original.csv', index=False)

# Save scaled data (for linear models and MLP)
X_train_scaled.to_csv('../data/processed/X_train_scaled.csv', index=False)
X_val_scaled.to_csv('../data/processed/X_val_scaled.csv', index=False)
X_test_scaled.to_csv('../data/processed/X_test_scaled.csv', index=False)

# Save preprocessing artifacts
preprocessing_artifacts = {
    'scaler': scaler,
    'frequent_skills': frequent_skills,
    'experience_order': experience_order,
    'education_order': education_order,
    'onehot_cols': onehot_cols,
    'feature_columns': X_train.columns.tolist(),
    'cols_to_scale': cols_to_scale
}

joblib.dump(preprocessing_artifacts, '../data/processed/preprocessing_artifacts.joblib')

print("Preprocessed data saved to ../data/processed/")
print("Files:")
for f in sorted(os.listdir('../data/processed')):
    print(f"  - {f}")
# Out:
# Preprocessed data saved to ../data/processed/
# Files:
#   - X_test.csv
#   - X_test_scaled.csv
#   - X_train.csv
#   - X_train_scaled.csv
#   - X_val.csv
#   - X_val_scaled.csv
#   - preprocessing_artifacts.joblib
#   - y_test.csv
#   - y_test_original.csv
#   - y_train.csv
#   - y_train_original.csv
#   - y_val.csv
#   - y_val_original.csv

# %% [markdown]
# ## Summary
#
# ### Preprocessing Steps Completed:
# 1. **Dropped columns**: Removed identifiers and expected low-value features
# 2. **Missing values**: No missing values to handle
# 3. **Job-title keywords**: Pick out keywords in job-title as columns and indicate 1 for presence of keyword
# 4. **Train/Val/Test split**: 70/10/20, stratified by experience_level
# 5. **Outlier handling**: IQR-based winsorization on salary_usd
# 6. **Log-transform**: Applied `log1p` to salary for normalized target distribution
# 7. **Skills stack count**: Group skills required into stacks and count the number of skills for each stack
# 8. **Ordinal encoding**: experience_level (EN→EX), education_required (Associate→PhD)
# 9. **One-hot encoding**: years_experience, benefits_score, skills_deep_learning_count, skills_big_data_count, skills_cloud_count, skills_data_count, experience_level_enc, education_required_enc
# 10. **Scaling**: StandardScaler on numerical features (fitted on training data only)
#
# ### Output:
# - Unscaled data for tree-based models (Random Forest, XGBoost, Decision Tree, Gradient Boosting)
# - Scaled data for linear models and neural networks
# - Original-scale targets for dollar-based evaluation
# - Preprocessing artifacts for inference pipeline
